# %% [markdown]
# **imports**

# %%
import pandas as pd

# %% [markdown]
# **This function will add a new column summarizing the measures**

# %%
def pm_per_month(row):
    columns = [f'D0{i+1}' if i < 9 else f'D{i+1}' for i in range(31)]
    summation = 0
    j = 0
    for i in columns:
        if row[i] != 0:
            row['total'] += row[i]
            j +=1
    row['total'] /= j
    return row['total']

# %%
y2010 = pd.read_csv('../data/data2010.csv', sep=';')
y2011 = pd.read_csv('../data/data2011.csv', sep=';')
y2012 = pd.read_csv('../data/data2012.csv', sep=';')
y2013 = pd.read_csv('../data/data2013.csv', sep=';')
y2014 = pd.read_csv('../data/data2014.csv', sep=';')
y2015 = pd.read_csv('../data/data2015.csv', sep=';')
y2016 = pd.read_csv('../data/data2016.csv', sep=';')
y2017 = pd.read_csv('../data/data2017.csv', sep=';')
y2018 = pd.read_csv('../data/data2018.csv', sep=';')
y2019 = pd.read_csv('../data/data2019.csv', sep=';')
y2020 = pd.read_csv('../data/datos202012.csv', sep=';')
y2021 = pd.read_csv('../data/datos202112.csv', sep=';')

# %%
y2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1808 non-null   int64
#  1   MUNICIPIO       1808 non-null   int64
#  2   ESTACION        1808 non-null   int64
#  3   MAGNITUD        1808 non-null   int64
#  4   PUNTO_MUESTREO  1808 non-null   object
#  5   ANO             1808 non-null   int64
#  6   MES             1808 non-null   int64
#  7   D01             1808 non-null   float64
#  8   V01             1808 non-null   object
#  9   D02             1808 non-null   float64
#  10  V02             1808 non-null   object
#  11  D03             1808 non-null   float64
#  12  V03             1808 non-null   object
#  13  D04             1808 non-null   float64
#  14  V04             1808 non-null   object
#  15  D05             1808 non-null   float64
#  16  V05             1808 non-null   object
# ...

# %%
y2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1848 entries, 0 to 1847
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1848 non-null   int64
#  1   MUNICIPIO       1848 non-null   int64
#  2   ESTACION        1848 non-null   int64
#  3   MAGNITUD        1848 non-null   int64
#  4   PUNTO_MUESTREO  1848 non-null   object
#  5   ANO             1848 non-null   int64
#  6   MES             1848 non-null   int64
#  7   D01             1848 non-null   float64
#  8   V01             1848 non-null   object
#  9   D02             1848 non-null   float64
#  10  V02             1848 non-null   object
#  11  D03             1848 non-null   float64
#  12  V03             1848 non-null   object
#  13  D04             1848 non-null   float64
#  14  V04             1848 non-null   object
#  15  D05             1848 non-null   float64
#  16  V05             1848 non-null   object
# ...

# %%
y2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1830 non-null   int64
#  1   MUNICIPIO       1830 non-null   int64
#  2   ESTACION        1830 non-null   int64
#  3   MAGNITUD        1830 non-null   int64
#  4   PUNTO_MUESTREO  1830 non-null   object
#  5   ANO             1830 non-null   int64
#  6   MES             1830 non-null   int64
#  7   D01             1830 non-null   float64
#  8   V01             1830 non-null   object
#  9   D02             1830 non-null   float64
#  10  V02             1830 non-null   object
#  11  D03             1830 non-null   float64
#  12  V03             1830 non-null   object
#  13  D04             1830 non-null   float64
#  14  V04             1830 non-null   object
#  15  D05             1830 non-null   float64
#  16  V05             1830 non-null   object
# ...

# %%
y2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1812 entries, 0 to 1811
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1812 non-null   int64
#  1   MUNICIPIO       1812 non-null   int64
#  2   ESTACION        1812 non-null   int64
#  3   MAGNITUD        1812 non-null   int64
#  4   PUNTO_MUESTREO  1812 non-null   object
#  5   ANO             1812 non-null   int64
#  6   MES             1812 non-null   int64
#  7   D01             1812 non-null   float64
#  8   V01             1812 non-null   object
#  9   D02             1812 non-null   float64
#  10  V02             1812 non-null   object
#  11  D03             1812 non-null   float64
#  12  V03             1812 non-null   object
#  13  D04             1812 non-null   float64
#  14  V04             1812 non-null   object
#  15  D05             1812 non-null   float64
#  16  V05             1812 non-null   object
# ...

# %%
y2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1805 entries, 0 to 1804
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1805 non-null   int64
#  1   MUNICIPIO       1805 non-null   int64
#  2   ESTACION        1805 non-null   int64
#  3   MAGNITUD        1805 non-null   int64
#  4   PUNTO_MUESTREO  1805 non-null   object
#  5   ANO             1805 non-null   int64
#  6   MES             1805 non-null   int64
#  7   D01             1805 non-null   float64
#  8   V01             1805 non-null   object
#  9   D02             1805 non-null   float64
#  10  V02             1805 non-null   object
#  11  D03             1805 non-null   float64
#  12  V03             1805 non-null   object
#  13  D04             1805 non-null   float64
#  14  V04             1805 non-null   object
#  15  D05             1805 non-null   float64
#  16  V05             1805 non-null   object
# ...

# %%
y2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1812 entries, 0 to 1811
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1812 non-null   int64
#  1   MUNICIPIO       1812 non-null   int64
#  2   ESTACION        1812 non-null   int64
#  3   MAGNITUD        1812 non-null   int64
#  4   PUNTO_MUESTREO  1812 non-null   object
#  5   ANO             1812 non-null   int64
#  6   MES             1812 non-null   int64
#  7   D01             1812 non-null   float64
#  8   V01             1812 non-null   object
#  9   D02             1812 non-null   float64
#  10  V02             1812 non-null   object
#  11  D03             1812 non-null   float64
#  12  V03             1812 non-null   object
#  13  D04             1812 non-null   float64
#  14  V04             1812 non-null   object
#  15  D05             1812 non-null   float64
#  16  V05             1812 non-null   object
# ...

# %%
y2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1812 entries, 0 to 1811
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1812 non-null   int64
#  1   MUNICIPIO       1812 non-null   int64
#  2   ESTACION        1812 non-null   int64
#  3   MAGNITUD        1812 non-null   int64
#  4   PUNTO_MUESTREO  1812 non-null   object
#  5   ANO             1812 non-null   int64
#  6   MES             1812 non-null   int64
#  7   D01             1812 non-null   float64
#  8   V01             1812 non-null   object
#  9   D02             1812 non-null   float64
#  10  V02             1812 non-null   object
#  11  D03             1812 non-null   float64
#  12  V03             1812 non-null   object
#  13  D04             1812 non-null   float64
#  14  V04             1812 non-null   object
#  15  D05             1812 non-null   float64
#  16  V05             1812 non-null   object
# ...

# %%
y2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1812 entries, 0 to 1811
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1812 non-null   int64
#  1   MUNICIPIO       1812 non-null   int64
#  2   ESTACION        1812 non-null   int64
#  3   MAGNITUD        1812 non-null   int64
#  4   PUNTO_MUESTREO  1812 non-null   object
#  5   ANO             1812 non-null   int64
#  6   MES             1812 non-null   int64
#  7   D01             1812 non-null   float64
#  8   V01             1812 non-null   object
#  9   D02             1812 non-null   float64
#  10  V02             1812 non-null   object
#  11  D03             1812 non-null   float64
#  12  V03             1812 non-null   object
#  13  D04             1812 non-null   float64
#  14  V04             1812 non-null   object
#  15  D05             1812 non-null   float64
#  16  V05             1812 non-null   object
# ...

# %%
y2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1806 entries, 0 to 1805
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1806 non-null   int64
#  1   MUNICIPIO       1806 non-null   int64
#  2   ESTACION        1806 non-null   int64
#  3   MAGNITUD        1806 non-null   int64
#  4   PUNTO_MUESTREO  1806 non-null   object
#  5   ANO             1806 non-null   int64
#  6   MES             1806 non-null   int64
#  7   D01             1806 non-null   float64
#  8   V01             1806 non-null   object
#  9   D02             1806 non-null   float64
#  10  V02             1806 non-null   object
#  11  D03             1806 non-null   float64
#  12  V03             1806 non-null   object
#  13  D04             1806 non-null   float64
#  14  V04             1806 non-null   object
#  15  D05             1806 non-null   float64
#  16  V05             1806 non-null   object
# ...

# %%
y2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836 entries, 0 to 1835
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       1836 non-null   int64
#  1   MUNICIPIO       1836 non-null   int64
#  2   ESTACION        1836 non-null   int64
#  3   MAGNITUD        1836 non-null   int64
#  4   PUNTO_MUESTREO  1836 non-null   object
#  5   ANO             1836 non-null   int64
#  6   MES             1836 non-null   int64
#  7   D01             1836 non-null   float64
#  8   V01             1836 non-null   object
#  9   D02             1836 non-null   float64
#  10  V02             1836 non-null   object
#  11  D03             1836 non-null   float64
#  12  V03             1836 non-null   object
#  13  D04             1836 non-null   float64
#  14  V04             1836 non-null   object
#  15  D05             1836 non-null   float64
#  16  V05             1836 non-null   object
# ...

# %% [markdown]
# Exploring particles <2.5 micrograms
# ==

# %%
pm2019 = y2019[y2019['MAGNITUD'] == 9]
pm2019
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 108          28         79         8         9  28079008_9_47  2019    1
# 109          28         79         8         9  28079008_9_47  2019    2
# 110          28         79         8         9  28079008_9_47  2019    3
# 111          28         79         8         9  28079008_9_47  2019    4
# 112          28         79         8         9  28079008_9_47  2019    5
# ...         ...        ...       ...       ...            ...   ...  ...
# 1567         28         79        56         9  28079056_9_47  2019    8
# 1568         28         79        56         9  28079056_9_47  2019    9
# 1569         28         79        56         9  28079056_9_47  2019   10
# 1570         28         79        56         9  28079056_9_47  2019   11
# 1571         28         79        56         9  28079056_9_47  2019   12
#
#        D01 V01   D02  ...   D27  V27   D28  V28   D29  V29   D30  V30   D31  \
# ...

# %%
pm2018 = y2018[y2018['MAGNITUD'] == 9]
pm2018
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 108          28         79         8         9  28079008_9_47  2018    1
# 109          28         79         8         9  28079008_9_47  2018    2
# 110          28         79         8         9  28079008_9_47  2018    3
# 111          28         79         8         9  28079008_9_47  2018    4
# 112          28         79         8         9  28079008_9_47  2018    5
# ...         ...        ...       ...       ...            ...   ...  ...
# 1321         28         79        50         9  28079050_9_47  2018    8
# 1322         28         79        50         9  28079050_9_47  2018    9
# 1323         28         79        50         9  28079050_9_47  2018   10
# 1324         28         79        50         9  28079050_9_47  2018   11
# 1325         28         79        50         9  28079050_9_47  2018   12
#
#        D01 V01   D02  ...   D27  V27   D28  V28   D29  V29   D30  V30   D31  \
# ...

# %%
pm2018['total'] = pm2018.apply(lambda x : pm_per_month(x), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/m2_ih/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/miniconda3/envs/m2_ih/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/miniconda3/envs/m2_ih/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pm2018 = y2018[y2018['MAGNITUD'] == 9]
pm2018['total'] = [i for i in range(len(pm2018))]
pm2018['total'] = pm2018.apply(lambda x : pm_per_month(x), axis=1)
pm2018
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1707219017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2018['total'] = [i for i in range(len(pm2018))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1707219017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2018['total'] = pm2018.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2019 = y2019[y2019['MAGNITUD'] == 9]
pm2019['total'] = [i for i in range(len(pm2019))]
pm2019['total'] = pm2019.apply(lambda x : pm_per_month(x), axis=1)
pm2019
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/893672357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2019['total'] = [i for i in range(len(pm2019))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/893672357.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2019['total'] = pm2019.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2017 = y2017[y2017['MAGNITUD'] == 9]
pm2017['total'] = [i for i in range(len(pm2017))]
pm2017['total'] = pm2017.apply(lambda x : pm_per_month(x), axis=1)
pm2017
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2875457820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2017['total'] = [i for i in range(len(pm2017))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2875457820.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2017['total'] = pm2017.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2016 = y2016[y2016['MAGNITUD'] == 9]
pm2016['total'] = [i for i in range(len(pm2016))]
pm2016['total'] = pm2016.apply(lambda x : pm_per_month(x), axis=1)
pm2016
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1396590018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2016['total'] = [i for i in range(len(pm2016))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1396590018.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2016['total'] = pm2016.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2015 = y2015[y2015['MAGNITUD'] == 9]
pm2015['total'] = [i for i in range(len(pm2015))]
pm2015['total'] = pm2015.apply(lambda x : pm_per_month(x), axis=1)
pm2015
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/725913540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2015['total'] = [i for i in range(len(pm2015))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/725913540.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2015['total'] = pm2015.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2014 = y2014[y2014['MAGNITUD'] == 9]
pm2014['total'] = [i for i in range(len(pm2014))]
pm2014['total'] = pm2014.apply(lambda x : pm_per_month(x), axis=1)
pm2014
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1642419583.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2014['total'] = [i for i in range(len(pm2014))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1642419583.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2014['total'] = pm2014.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2013 = y2013[y2013['MAGNITUD'] == 9]
pm2013['total'] = [i for i in range(len(pm2013))]
pm2013['total'] = pm2013.apply(lambda x : pm_per_month(x), axis=1)
pm2013
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2492119050.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2013['total'] = [i for i in range(len(pm2013))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2492119050.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2013['total'] = pm2013.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2012 = y2012[y2012['MAGNITUD'] == 9]
pm2012['total'] = [i for i in range(len(pm2012))]
pm2012['total'] = pm2012.apply(lambda x : pm_per_month(x), axis=1)
pm2012
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2089494871.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2012['total'] = [i for i in range(len(pm2012))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2089494871.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2012['total'] = pm2012.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2011 = y2011[y2011['MAGNITUD'] == 9]
pm2011['total'] = [i for i in range(len(pm2011))]
pm2011['total'] = pm2011.apply(lambda x : pm_per_month(x), axis=1)
pm2011
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1017190952.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2011['total'] = [i for i in range(len(pm2011))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1017190952.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2011['total'] = pm2011.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2010 = y2010[y2010['MAGNITUD'] == 9]
pm2010['total'] = [i for i in range(len(pm2010))]
pm2010['total'] = pm2010.apply(lambda x : pm_per_month(x), axis=1)
pm2010
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2113356566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2010['total'] = [i for i in range(len(pm2010))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2113356566.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm2010['total'] = pm2010.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2010['total'].describe()
# Out:
# count    66.000000
# mean     13.182540
# std       3.092031
# min       6.266667
# 25%      11.504032
# 50%      13.082796
# 75%      15.027778
# max      22.857143
# Name: total, dtype: float64

# %%
pm2013['total'].describe()
# Out:
# count    72.000000
# mean     11.392446
# std       2.850565
# min       6.451613
# 25%       9.633929
# 50%      11.150000
# 75%      12.575000
# max      23.225806
# Name: total, dtype: float64

# %%
pm2015['total'].describe()
# Out:
# count    72.000000
# mean     12.471818
# std       4.249297
# min       4.967742
# 25%       9.983871
# 50%      11.709677
# 75%      13.225806
# max      26.516129
# Name: total, dtype: float64

# %%
pm2017['total'].describe()
# Out:
# count    72.000000
# mean     11.116881
# std       1.970739
# min       8.064516
# 25%       9.785484
# 50%      10.951075
# 75%      12.348214
# max      16.548387
# Name: total, dtype: float64

# %%
pm2019['total'].describe()
# Out:
# count    84.000000
# mean     11.270451
# std       3.314921
# min       5.100000
# 25%       8.891667
# 50%      10.741935
# 75%      13.556452
# max      20.870968
# Name: total, dtype: float64

# %% [markdown]
# Exploring particles <10 micrograms
# ==

# %%
pm10_2010 = y2010[y2010['MAGNITUD'] == 10]
pm10_2010['total'] = [i for i in range(len(pm10_2010))]
pm10_2010['total'] = pm10_2010.apply(lambda x : pm_per_month(x), axis=1)
pm10_2010
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3210248712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2010['total'] = [i for i in range(len(pm10_2010))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3210248712.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2010['total'] = pm10_2010.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2011 = y2011[y2011['MAGNITUD'] == 10]
pm10_2011['total'] = [i for i in range(len(pm10_2011))]
pm10_2011['total'] = pm10_2011.apply(lambda x : pm_per_month(x), axis=1)
pm10_2011
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/227997542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2011['total'] = [i for i in range(len(pm10_2011))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/227997542.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2011['total'] = pm10_2011.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2012 = y2012[y2012['MAGNITUD'] == 10]
pm10_2012['total'] = [i for i in range(len(pm10_2012))]
pm10_2012['total'] = pm10_2012.apply(lambda x : pm_per_month(x), axis=1)
pm10_2012
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4144726719.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2012['total'] = [i for i in range(len(pm10_2012))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4144726719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2012['total'] = pm10_2012.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2013 = y2013[y2013['MAGNITUD'] == 10]
pm10_2013['total'] = [i for i in range(len(pm10_2013))]
pm10_2013['total'] = pm10_2013.apply(lambda x : pm_per_month(x), axis=1)
pm10_2013
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2018131712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2013['total'] = [i for i in range(len(pm10_2013))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2018131712.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2013['total'] = pm10_2013.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2014 = y2014[y2014['MAGNITUD'] == 10]
pm10_2014['total'] = [i for i in range(len(pm10_2014))]
pm10_2014['total'] = pm10_2014.apply(lambda x : pm_per_month(x), axis=1)
pm10_2014
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/963626272.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2014['total'] = [i for i in range(len(pm10_2014))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/963626272.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2014['total'] = pm10_2014.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2015 = y2015[y2015['MAGNITUD'] == 10]
pm10_2015['total'] = [i for i in range(len(pm10_2015))]
pm10_2015['total'] = pm10_2015.apply(lambda x : pm_per_month(x), axis=1)
pm10_2015
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3383298957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2015['total'] = [i for i in range(len(pm10_2015))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3383298957.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2015['total'] = pm10_2015.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2016 = y2016[y2016['MAGNITUD'] == 10]
pm10_2016['total'] = [i for i in range(len(pm10_2016))]
pm10_2016['total'] = pm10_2016.apply(lambda x : pm_per_month(x), axis=1)
pm10_2016
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3770725947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2016['total'] = [i for i in range(len(pm10_2016))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3770725947.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2016['total'] = pm10_2016.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2017 = y2017[y2017['MAGNITUD'] == 10]
pm10_2017['total'] = [i for i in range(len(pm10_2017))]
pm10_2017['total'] = pm10_2017.apply(lambda x : pm_per_month(x), axis=1)
pm10_2017
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4037048677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2017['total'] = [i for i in range(len(pm10_2017))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4037048677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2017['total'] = pm10_2017.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2018 = y2018[y2018['MAGNITUD'] == 10]
pm10_2018['total'] = [i for i in range(len(pm10_2018))]
pm10_2018['total'] = pm10_2018.apply(lambda x : pm_per_month(x), axis=1)
pm10_2018
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2221148439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2018['total'] = [i for i in range(len(pm10_2018))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2221148439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2018['total'] = pm10_2018.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2019 = y2019[y2019['MAGNITUD'] == 10]
pm10_2019['total'] = [i for i in range(len(pm10_2019))]
pm10_2019['total'] = pm10_2019.apply(lambda x : pm_per_month(x), axis=1)
pm10_2019
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3432944937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2019['total'] = [i for i in range(len(pm10_2019))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3432944937.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2019['total'] = pm10_2019.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2011['total'].describe()
# Out:
# count    144.000000
# mean      25.798944
# std        4.739754
# min       16.193548
# 25%       22.758333
# 50%       24.882184
# 75%       28.354839
# max       41.533333
# Name: total, dtype: float64

# %%
pm10_2013['total'].describe()
# Out:
# count    144.000000
# mean      21.075492
# std        8.782510
# min        8.571429
# 25%       16.112903
# 50%       19.077957
# 75%       24.708333
# max       92.928571
# Name: total, dtype: float64

# %%
pm10_2015['total'].describe()
# Out:
# count    144.000000
# mean      27.601130
# std       52.189683
# min        6.500000
# 25%       19.161828
# 50%       22.100000
# 75%       27.137097
# max      644.709677
# Name: total, dtype: float64

# %%
pm10_2014['total'].describe()
# Out:
# count    144.000000
# mean      21.649641
# std        4.570365
# min        9.785714
# 25%       19.290323
# 50%       21.655376
# 75%       24.386290
# max       35.290323
# Name: total, dtype: float64

# %%
pm10_2017['total'].describe()
# Out:
# count    144.000000
# mean      22.338022
# std        5.156026
# min       12.258065
# 25%       18.218548
# 50%       21.684946
# 75%       25.719758
# max       34.642857
# Name: total, dtype: float64

# %%
pm10_2018['total'].describe()
# Out:
# count    144.000000
# mean      21.295465
# std       14.573757
# min        5.800000
# 25%       14.124194
# 50%       20.130760
# 75%       24.683333
# max      173.933333
# Name: total, dtype: float64

# %%
pm10_2019['total'].describe()
# Out:
# count    156.000000
# mean      20.119061
# std        6.123129
# min        7.833333
# 25%       15.645161
# 50%       19.322581
# 75%       24.303571
# max       37.000000
# Name: total, dtype: float64

# %% [markdown]
# Exploring Carbon Monoxide (CO)
# ==

# %%
co_2010 = y2010[y2010['MAGNITUD'] == 6]
co_2010['total'] = [i for i in range(len(co_2010))]
co_2010['total'] = co_2010.apply(lambda x : pm_per_month(x), axis=1)
co_2010
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3500011013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2010['total'] = [i for i in range(len(co_2010))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3500011013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2010['total'] = co_2010.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2011 = y2011[y2011['MAGNITUD'] == 6]
co_2011['total'] = [i for i in range(len(co_2011))]
co_2011['total'] = co_2011.apply(lambda x : pm_per_month(x), axis=1)
co_2011
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1619726276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2011['total'] = [i for i in range(len(co_2011))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1619726276.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2011['total'] = co_2011.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2012 = y2012[y2012['MAGNITUD'] == 6]
co_2012['total'] = [i for i in range(len(co_2012))]
co_2012['total'] = co_2012.apply(lambda x : pm_per_month(x), axis=1)
co_2012
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/10324145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2012['total'] = [i for i in range(len(co_2012))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/10324145.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2012['total'] = co_2012.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2013 = y2013[y2013['MAGNITUD'] == 6]
co_2013['total'] = [i for i in range(len(co_2013))]
co_2013['total'] = co_2013.apply(lambda x : pm_per_month(x), axis=1)
co_2013
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3320850724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2013['total'] = [i for i in range(len(co_2013))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3320850724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2013['total'] = co_2013.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2014 = y2014[y2014['MAGNITUD'] == 6]
co_2014['total'] = [i for i in range(len(co_2014))]
co_2014['total'] = co_2014.apply(lambda x : pm_per_month(x), axis=1)
co_2014
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2123982506.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2014['total'] = [i for i in range(len(co_2014))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2123982506.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2014['total'] = co_2014.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2015 = y2015[y2015['MAGNITUD'] == 6]
co_2015['total'] = [i for i in range(len(co_2015))]
co_2015['total'] = co_2015.apply(lambda x : pm_per_month(x), axis=1)
co_2015
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3595707926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2015['total'] = [i for i in range(len(co_2015))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3595707926.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2015['total'] = co_2015.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2016 = y2016[y2016['MAGNITUD'] == 6]
co_2016['total'] = [i for i in range(len(co_2016))]
co_2016['total'] = co_2016.apply(lambda x : pm_per_month(x), axis=1)
co_2016
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2550744998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2016['total'] = [i for i in range(len(co_2016))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2550744998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2016['total'] = co_2016.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2017 = y2017[y2017['MAGNITUD'] == 6]
co_2017['total'] = [i for i in range(len(co_2017))]
co_2017['total'] = co_2017.apply(lambda x : pm_per_month(x), axis=1)
co_2017
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3791099263.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2017['total'] = [i for i in range(len(co_2017))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3791099263.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2017['total'] = co_2017.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2018 = y2018[y2018['MAGNITUD'] == 6]
co_2018['total'] = [i for i in range(len(co_2018))]
co_2018['total'] = co_2018.apply(lambda x : pm_per_month(x), axis=1)
co_2018
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/852782086.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2018['total'] = [i for i in range(len(co_2018))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/852782086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2018['total'] = co_2018.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2019 = y2019[y2019['MAGNITUD'] == 6]
co_2019['total'] = [i for i in range(len(co_2019))]
co_2019['total'] = co_2019.apply(lambda x : pm_per_month(x), axis=1)
co_2019
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3417411329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2019['total'] = [i for i in range(len(co_2019))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3417411329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2019['total'] = co_2019.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %% [markdown]
# Exploring nitrogen monoxide (NO)
# ==

# %%
no_2010 = y2010[y2010['MAGNITUD'] == 7]
no_2010['total'] = [i for i in range(len(no_2010))]
no_2010['total'] = no_2010.apply(lambda x : pm_per_month(x), axis=1)
no_2010
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2220250674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2010['total'] = [i for i in range(len(no_2010))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2220250674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2010['total'] = no_2010.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2011 = y2011[y2011['MAGNITUD'] == 7]
no_2011['total'] = [i for i in range(len(no_2011))]
no_2011['total'] = no_2011.apply(lambda x : pm_per_month(x), axis=1)
no_2011
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/103558551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2011['total'] = [i for i in range(len(no_2011))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/103558551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2011['total'] = no_2011.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2012 = y2012[y2012['MAGNITUD'] == 7]
no_2012['total'] = [i for i in range(len(no_2012))]
no_2012['total'] = no_2012.apply(lambda x : pm_per_month(x), axis=1)
no_2012
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1000723466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2012['total'] = [i for i in range(len(no_2012))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1000723466.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2012['total'] = no_2012.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2013 = y2013[y2013['MAGNITUD'] == 7]
no_2013['total'] = [i for i in range(len(no_2013))]
no_2013['total'] = no_2013.apply(lambda x : pm_per_month(x), axis=1)
no_2013
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/61439999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2013['total'] = [i for i in range(len(no_2013))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/61439999.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2013['total'] = no_2013.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2014 = y2014[y2014['MAGNITUD'] == 7]
no_2014['total'] = [i for i in range(len(no_2014))]
no_2014['total'] = no_2014.apply(lambda x : pm_per_month(x), axis=1)
no_2014
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1540727495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2014['total'] = [i for i in range(len(no_2014))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1540727495.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2014['total'] = no_2014.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2015 = y2015[y2015['MAGNITUD'] == 7]
no_2015['total'] = [i for i in range(len(no_2015))]
no_2015['total'] = no_2015.apply(lambda x : pm_per_month(x), axis=1)
no_2015
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1515532409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2015['total'] = [i for i in range(len(no_2015))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1515532409.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2015['total'] = no_2015.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2016 = y2016[y2016['MAGNITUD'] == 7]
no_2016['total'] = [i for i in range(len(no_2016))]
no_2016['total'] = no_2016.apply(lambda x : pm_per_month(x), axis=1)
no_2016
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2232332487.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2016['total'] = [i for i in range(len(no_2016))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2232332487.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2016['total'] = no_2016.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2017 = y2017[y2017['MAGNITUD'] == 7]
no_2017['total'] = [i for i in range(len(no_2017))]
no_2017['total'] = no_2017.apply(lambda x : pm_per_month(x), axis=1)
no_2017
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3313347431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2017['total'] = [i for i in range(len(no_2017))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3313347431.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2017['total'] = no_2017.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2018 = y2018[y2018['MAGNITUD'] == 7]
no_2018['total'] = [i for i in range(len(no_2018))]
no_2018['total'] = no_2018.apply(lambda x : pm_per_month(x), axis=1)
no_2018
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3847364231.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2018['total'] = [i for i in range(len(no_2018))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3847364231.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2018['total'] = no_2018.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2019 = y2019[y2019['MAGNITUD'] == 7]
no_2019['total'] = [i for i in range(len(no_2019))]
no_2019['total'] = no_2019.apply(lambda x : pm_per_month(x), axis=1)
no_2019
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4018558845.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2019['total'] = [i for i in range(len(no_2019))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/4018558845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2019['total'] = no_2019.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %% [markdown]
# Exploring NO2
# ==

# %%
no2_2010 = y2010[y2010['MAGNITUD'] == 8]
no2_2010['total'] = [i for i in range(len(no2_2010))]
no2_2010['total'] = no2_2010.apply(lambda x : pm_per_month(x), axis=1)
no2_2010
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/898689659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2010['total'] = [i for i in range(len(no2_2010))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/898689659.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2010['total'] = no2_2010.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2011 = y2011[y2011['MAGNITUD'] == 8]
no2_2011['total'] = [i for i in range(len(no2_2011))]
no2_2011['total'] = no2_2011.apply(lambda x : pm_per_month(x), axis=1)
no2_2011
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3250530158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2011['total'] = [i for i in range(len(no2_2011))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3250530158.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2011['total'] = no2_2011.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2012 = y2012[y2012['MAGNITUD'] == 8]
no2_2012['total'] = [i for i in range(len(no2_2012))]
no2_2012['total'] = no2_2012.apply(lambda x : pm_per_month(x), axis=1)
no2_2012
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2162376052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2012['total'] = [i for i in range(len(no2_2012))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2162376052.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2012['total'] = no2_2012.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2013 = y2013[y2013['MAGNITUD'] == 8]
no2_2013['total'] = [i for i in range(len(no2_2013))]
no2_2013['total'] = no2_2013.apply(lambda x : pm_per_month(x), axis=1)
no2_2013
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3053812420.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2013['total'] = [i for i in range(len(no2_2013))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3053812420.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2013['total'] = no2_2013.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2014 = y2014[y2014['MAGNITUD'] == 8]
no2_2014['total'] = [i for i in range(len(no2_2014))]
no2_2014['total'] = no2_2014.apply(lambda x : pm_per_month(x), axis=1)
no2_2014
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/198117068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2014['total'] = [i for i in range(len(no2_2014))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/198117068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2014['total'] = no2_2014.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2015 = y2015[y2015['MAGNITUD'] == 8]
no2_2015['total'] = [i for i in range(len(no2_2015))]
no2_2015['total'] = no2_2015.apply(lambda x : pm_per_month(x), axis=1)
no2_2015
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3976271788.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2015['total'] = [i for i in range(len(no2_2015))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3976271788.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2015['total'] = no2_2015.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2016 = y2016[y2016['MAGNITUD'] == 8]
no2_2016['total'] = [i for i in range(len(no2_2016))]
no2_2016['total'] = no2_2016.apply(lambda x : pm_per_month(x), axis=1)
no2_2016
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3540956115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2016['total'] = [i for i in range(len(no2_2016))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3540956115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2016['total'] = no2_2016.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2017 = y2017[y2017['MAGNITUD'] == 8]
no2_2017['total'] = [i for i in range(len(no2_2017))]
no2_2017['total'] = no2_2017.apply(lambda x : pm_per_month(x), axis=1)
no2_2017
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1847188539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2017['total'] = [i for i in range(len(no2_2017))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1847188539.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2017['total'] = no2_2017.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2018 = y2018[y2018['MAGNITUD'] == 8]
no2_2018['total'] = [i for i in range(len(no2_2018))]
no2_2018['total'] = no2_2018.apply(lambda x : pm_per_month(x), axis=1)
no2_2018
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/708183760.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2018['total'] = [i for i in range(len(no2_2018))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/708183760.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2018['total'] = no2_2018.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2019 = y2019[y2019['MAGNITUD'] == 8]
no2_2019['total'] = [i for i in range(len(no2_2019))]
no2_2019['total'] = no2_2019.apply(lambda x : pm_per_month(x), axis=1)
no2_2019
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1627154106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2019['total'] = [i for i in range(len(no2_2019))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1627154106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2019['total'] = no2_2019.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 108 to 1329
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       66 non-null     int64
#  1   MUNICIPIO       66 non-null     int64
#  2   ESTACION        66 non-null     int64
#  3   MAGNITUD        66 non-null     int64
#  4   PUNTO_MUESTREO  66 non-null     object
#  5   ANO             66 non-null     int64
#  6   MES             66 non-null     int64
#  7   D01             66 non-null     float64
#  8   V01             66 non-null     object
#  9   D02             66 non-null     float64
#  10  V02             66 non-null     object
#  11  D03             66 non-null     float64
#  12  V03             66 non-null     object
#  13  D04             66 non-null     float64
#  14  V04             66 non-null     object
#  15  D05             66 non-null     float64
#  16  V05             66 non-null     object
# ...

# %%
pm2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 108 to 1571
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PROVINCIA       84 non-null     int64
#  1   MUNICIPIO       84 non-null     int64
#  2   ESTACION        84 non-null     int64
#  3   MAGNITUD        84 non-null     int64
#  4   PUNTO_MUESTREO  84 non-null     object
#  5   ANO             84 non-null     int64
#  6   MES             84 non-null     int64
#  7   D01             84 non-null     float64
#  8   V01             84 non-null     object
#  9   D02             84 non-null     float64
#  10  V02             84 non-null     object
#  11  D03             84 non-null     float64
#  12  V03             84 non-null     object
#  13  D04             84 non-null     float64
#  14  V04             84 non-null     object
#  15  D05             84 non-null     float64
#  16  V05             84 non-null     object
# ...

# %%
pm = pd.concat([pm2010, pm2011, pm2012, pm2013, pm2014, pm2015, pm2016, pm2017, pm2018, pm2019], axis=0)
pm = pm.reset_index()
pm
# Out:
#      index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  \
# 0      108         28         79         8         9  28079008_9_47  2010
# 1      109         28         79         8         9  28079008_9_47  2010
# 2      110         28         79         8         9  28079008_9_47  2010
# 3      111         28         79         8         9  28079008_9_47  2010
# 4      112         28         79         8         9  28079008_9_47  2010
# ..     ...        ...        ...       ...       ...            ...   ...
# 715   1567         28         79        56         9  28079056_9_47  2019
# 716   1568         28         79        56         9  28079056_9_47  2019
# 717   1569         28         79        56         9  28079056_9_47  2019
# 718   1570         28         79        56         9  28079056_9_47  2019
# 719   1571         28         79        56         9  28079056_9_47  2019
#
#      MES   D01 V01  ...  V27   D28  V28   D29  V29   D30  V30   D31  V31  \
# ...

# %%
pm10 = pd.concat([pm10_2010,pm10_2011, pm10_2012, pm10_2013, pm10_2014, pm10_2015, pm10_2016, pm10_2017, pm10_2018, pm10_2019], axis=0)
pm10 = pm10.reset_index()
pm10
# Out:
#       index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  \
# 0       120         28         79         8        10  28079008_10_47  2010
# 1       121         28         79         8        10  28079008_10_47  2010
# 2       122         28         79         8        10  28079008_10_47  2010
# 3       123         28         79         8        10  28079008_10_47  2010
# 4       124         28         79         8        10  28079008_10_47  2010
# ...     ...        ...        ...       ...       ...             ...   ...
# 1441   1807         28         79        60        10  28079060_10_47  2019
# 1442   1808         28         79        60        10  28079060_10_47  2019
# 1443   1809         28         79        60        10  28079060_10_47  2019
# 1444   1810         28         79        60        10  28079060_10_47  2019
# 1445   1811         28         79        60        10  28079060_10_47  2019
#
# ...

# %%
co = pd.concat([co_2010, co_2011, co_2012, co_2013, co_2014, co_2015, co_2016, co_2017, co_2018, co_2019], axis=0)
co = co.reset_index()
co
# Out:
#       index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  \
# 0        12         28         79         4         6  28079004_6_48  2010
# 1        13         28         79         4         6  28079004_6_48  2010
# 2        14         28         79         4         6  28079004_6_48  2010
# 3        15         28         79         4         6  28079004_6_48  2010
# 4        16         28         79         4         6  28079004_6_48  2010
# ...     ...        ...        ...       ...       ...            ...   ...
# 1195   1627         28         79        57         6  28079057_6_48  2019
# 1196   1628         28         79        57         6  28079057_6_48  2019
# 1197   1629         28         79        57         6  28079057_6_48  2019
# 1198   1630         28         79        57         6  28079057_6_48  2019
# 1199   1631         28         79        57         6  28079057_6_48  2019
#
# ...

# %%
no = pd.concat([no_2010, no_2011, no_2012, no_2013, no_2014, no_2015, no_2016, no_2017, no_2018, no_2019], axis=0)
no = no.reset_index()
no
# Out:
#       index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  \
# 0        24         28         79         4         7   28079004_7_8  2010
# 1        25         28         79         4         7   28079004_7_8  2010
# 2        26         28         79         4         7   28079004_7_8  2010
# 3        27         28         79         4         7   28079004_7_8  2010
# 4        28         28         79         4         7   28079004_7_8  2010
# ...     ...        ...        ...       ...       ...            ...   ...
# 2867   1783         28         79        60         7   28079060_7_8  2019
# 2868   1784         28         79        60         7   28079060_7_8  2019
# 2869   1785         28         79        60         7   28079060_7_8  2019
# 2870   1786         28         79        60         7   28079060_7_8  2019
# 2871   1787         28         79        60         7   28079060_7_8  2019
#
# ...

# %%
no2 = pd.concat([no2_2010, no2_2011, no2_2012, no2_2013, no2_2014, no2_2015, no2_2016, no2_2017, no2_2018, no2_2019], axis=0)
no2 = no2.reset_index()
no2
# Out:
#       index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  \
# 0        36         28         79         4         8   28079004_8_8  2010
# 1        37         28         79         4         8   28079004_8_8  2010
# 2        38         28         79         4         8   28079004_8_8  2010
# 3        39         28         79         4         8   28079004_8_8  2010
# 4        40         28         79         4         8   28079004_8_8  2010
# ...     ...        ...        ...       ...       ...            ...   ...
# 2867   1795         28         79        60         8   28079060_8_8  2019
# 2868   1796         28         79        60         8   28079060_8_8  2019
# 2869   1797         28         79        60         8   28079060_8_8  2019
# 2870   1798         28         79        60         8   28079060_8_8  2019
# 2871   1799         28         79        60         8   28079060_8_8  2019
#
# ...

# %%
pm[pm['ANO'] == 2018]
# Out:
#      index  PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  \
# 570    108         28         79         8         9  28079008_9_47  2018
# 571    109         28         79         8         9  28079008_9_47  2018
# 572    110         28         79         8         9  28079008_9_47  2018
# 573    111         28         79         8         9  28079008_9_47  2018
# 574    112         28         79         8         9  28079008_9_47  2018
# ..     ...        ...        ...       ...       ...            ...   ...
# 631   1321         28         79        50         9  28079050_9_47  2018
# 632   1322         28         79        50         9  28079050_9_47  2018
# 633   1323         28         79        50         9  28079050_9_47  2018
# 634   1324         28         79        50         9  28079050_9_47  2018
# 635   1325         28         79        50         9  28079050_9_47  2018
#
#      MES   D01 V01  ...  V27   D28  V28   D29  V29   D30  V30   D31  V31  \
# ...

# %% [markdown]
# ---
#
# Saving transformed data
# ==

# %%
pm.to_csv('../data/transformed-data/pm.csv', sep=',')
pm10.to_csv('../data/transformed-data/pm10.csv', sep=',')
co.to_csv('../data/transformed-data/co.csv', sep=',')
no.to_csv('../data/transformed-data/no.csv', sep=',')
no2.to_csv('../data/transformed-data/no2.csv', sep=',')

# %%
pm10_2019
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# 120          28         79         8        10  28079008_10_47  2019    1
# 121          28         79         8        10  28079008_10_47  2019    2
# 122          28         79         8        10  28079008_10_47  2019    3
# 123          28         79         8        10  28079008_10_47  2019    4
# 124          28         79         8        10  28079008_10_47  2019    5
# ...         ...        ...       ...       ...             ...   ...  ...
# 1807         28         79        60        10  28079060_10_47  2019    8
# 1808         28         79        60        10  28079060_10_47  2019    9
# 1809         28         79        60        10  28079060_10_47  2019   10
# 1810         28         79        60        10  28079060_10_47  2019   11
# 1811         28         79        60        10  28079060_10_47  2019   12
#
#        D01 V01   D02  ... V27   D28 V28   D29 V29   D30 V30   D31 V31  \
# ...

# %%
pm2019['total'].describe()
# Out:
# count    84.000000
# mean     11.270451
# std       3.314921
# min       5.100000
# 25%       8.891667
# 50%      10.741935
# 75%      13.556452
# max      20.870968
# Name: total, dtype: float64

# %%
y2020
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 0            28         79         4         1  28079004_1_38  2020    1
# 1            28         79         4         1  28079004_1_38  2020    2
# 2            28         79         4         1  28079004_1_38  2020    3
# 3            28         79         4         1  28079004_1_38  2020    4
# 4            28         79         4         1  28079004_1_38  2020    5
# ...         ...        ...       ...       ...            ...   ...  ...
# 1831         28         79        60        14  28079060_14_6  2020    8
# 1832         28         79        60        14  28079060_14_6  2020    9
# 1833         28         79        60        14  28079060_14_6  2020   10
# 1834         28         79        60        14  28079060_14_6  2020   11
# 1835         28         79        60        14  28079060_14_6  2020   12
#
#        D01 V01   D02  ...   D27  V27   D28  V28   D29  V29   D30  V30   D31  \
# ...

# %%
no2_2020 = y2020[y2020['MAGNITUD'] == 8]
no2_2020['total'] = [i for i in range(len(no2_2020))]
no2_2020['total'] = no2_2020.apply(lambda x : pm_per_month(x), axis=1)
no2_2020
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/224510936.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2020['total'] = [i for i in range(len(no2_2020))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/224510936.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2020['total'] = no2_2020.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no2_2021 = y2021[y2021['MAGNITUD'] == 8]
no2_2021['total'] = [i for i in range(len(no2_2021))]
no2_2021['total'] = no2_2021.apply(lambda x : pm_per_month(x), axis=1)
no2_2021
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/892281993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2021['total'] = [i for i in range(len(no2_2021))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/892281993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2_2021['total'] = no2_2021.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2020 = y2020[y2020['MAGNITUD'] == 7]
no_2020['total'] = [i for i in range(len(no_2020))]
no_2020['total'] = no_2020.apply(lambda x : pm_per_month(x), axis=1)
no_2020
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2978389488.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2020['total'] = [i for i in range(len(no_2020))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2978389488.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2020['total'] = no_2020.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
no_2021 = y2021[y2021['MAGNITUD'] == 7]
no_2021['total'] = [i for i in range(len(no_2021))]
no_2021['total'] = no_2021.apply(lambda x : pm_per_month(x), axis=1)
no_2021
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1647099996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2021['total'] = [i for i in range(len(no_2021))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/1647099996.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2021['total'] = no_2021.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
co_2020 = y2020[y2020['MAGNITUD'] == 6]
co_2020['total'] = [i for i in range(len(co_2020))]
co_2020['total'] = co_2020.apply(lambda x : pm_per_month(x), axis=1)
co_2020
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/888677104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2020['total'] = [i for i in range(len(co_2020))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/888677104.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2020['total'] = co_2020.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
co_2021 = y2021[y2021['MAGNITUD'] == 6]
co_2021['total'] = [i for i in range(len(co_2021))]
co_2021['total'] = co_2021.apply(lambda x : pm_per_month(x), axis=1)
co_2021
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/573704253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2021['total'] = [i for i in range(len(co_2021))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/573704253.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_2021['total'] = co_2021.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  D01  \
# ...

# %%
pm_2020 = y2020[y2020['MAGNITUD'] == 9]
pm_2020['total'] = [i for i in range(len(pm_2020))]
pm_2020['total'] = pm_2020.apply(lambda x : pm_per_month(x), axis=1)
pm_2020
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/894617254.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm_2020['total'] = [i for i in range(len(pm_2020))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/894617254.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm_2020['total'] = pm_2020.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm_2021 = y2021[y2021['MAGNITUD'] == 9]
pm_2021['total'] = [i for i in range(len(pm_2021))]
pm_2021['total'] = pm_2021.apply(lambda x : pm_per_month(x), axis=1)
pm_2021
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/292474730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm_2021['total'] = [i for i in range(len(pm_2021))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/292474730.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm_2021['total'] = pm_2021.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2020 = y2020[y2020['MAGNITUD'] == 10]
pm10_2020['total'] = [i for i in range(len(pm10_2020))]
pm10_2020['total'] = pm10_2020.apply(lambda x : pm_per_month(x), axis=1)
pm10_2020
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3941037024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2020['total'] = [i for i in range(len(pm10_2020))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/3941037024.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2020['total'] = pm10_2020.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm10_2021 = y2021[y2021['MAGNITUD'] == 10]
pm10_2021['total'] = [i for i in range(len(pm10_2021))]
pm10_2021['total'] = pm10_2021.apply(lambda x : pm_per_month(x), axis=1)
pm10_2021
# Out:
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2336545669.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2021['total'] = [i for i in range(len(pm10_2021))]
# /var/folders/n3/xb6jll3d49q147jw5_13y6zm0000gn/T/ipykernel_4348/2336545669.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm10_2021['total'] = pm10_2021.apply(lambda x : pm_per_month(x), axis=1)
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# ...

# %%
pm_2020.to_csv('../data/transformed-data/pm_2020.csv', sep=',')
pm10_2020.to_csv('../data/transformed-data/pm10_2020.csv', sep=',')
co_2020.to_csv('../data/transformed-data/co_2020.csv', sep=',')
no_2020.to_csv('../data/transformed-data/no_2020.csv', sep=',')
no2_2020.to_csv('../data/transformed-data/no2_2020.csv', sep=',')

# %%
pm_2021.to_csv('../data/transformed-data/pm_2021.csv', sep=',')
pm10_2021.to_csv('../data/transformed-data/pm10_2021.csv', sep=',')
co_2021.to_csv('../data/transformed-data/co_2021.csv', sep=',')
no_2021.to_csv('../data/transformed-data/no_2021.csv', sep=',')
no2_2021.to_csv('../data/transformed-data/no2_2021.csv', sep=',')
